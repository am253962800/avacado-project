# %%
import pandas as pd
import numpy as np
import zipfile
import seaborn as sns

# %%
df=pd.read_csv('avocado.csv.zip')

# %%
df.head(50)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0            0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1            1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2            2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3            3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4            4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5            5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6            6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7            7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8            8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9            9  2015-10-25          1.07      74338.76   842.40   64757.44
# 10          10  2015-10-18          1.12      84843.44   924.86   75595.85
# ...

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (18249, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df.drop(['Unnamed: 0','XLarge Bags','Small Bags','Total Bags','Large Bags'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (18249, 9)

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#            type  year  region
# 0  conventional  2015  Albany
# 1  conventional  2015  Albany
# 2  conventional  2015  Albany
# 3  conventional  2015  Albany
# 4  conventional  2015  Albany

# %%
df[['Date','Month','Year']] = df['Date'].str.split("-",expand = True)

# %%
df[['Date','Month','Year']] = df[['Date','Month','Year']].astype(int)

# %%
df.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770          type  \
# 0  2015          1.33      64236.62  1036.74   54454.85   48.16  conventional
# 1  2015          1.35      54876.98   674.28   44638.81   58.33  conventional
# 2  2015          0.93     118220.22   794.70  109149.67  130.50  conventional
# 3  2015          1.08      78992.15  1132.00   71976.41   72.58  conventional
# 4  2015          1.28      51039.60   941.48   43838.39   75.78  conventional
#
#    year  region  Month  Year
# 0  2015  Albany     12    27
# 1  2015  Albany     12    20
# 2  2015  Albany     12    13
# 3  2015  Albany     12     6
# 4  2015  Albany     11    29

# %%
df['Year'].value_counts()
# Out:
# Year
# 4     756
# 11    756
# 18    755
# 25    755
# 1     648
# 26    648
# 5     648
# 12    648
# 3     648
# 8     648
# 15    648
# 22    648
# 24    648
# 17    648
# 10    648
# 19    648
# 7     540
# 14    540
# 21    540
# 28    540
# 27    540
# 20    540
# 29    540
# 13    540
# 6     539
# 2     432
# 9     432
# 23    432
# 30    432
# 31    432
# 16    432
# Name: count, dtype: int64

# %%
df['year'].value_counts()
# Out:
# year
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: count, dtype: int64

# %%
df.drop(['year'],axis=1, inplace=True)

# %%
df['type'].nunique()
# Out:
# 2

# %%
df.drop(['type'],axis=1, inplace=True)

# %%
df['region'].nunique()
# Out:
# 54

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  int32
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   region        18249 non-null  object
#  7   Month         18249 non-null  int32
#  8   Year          18249 non-null  int32
# dtypes: float64(5), int32(3), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# # EDA

# %%
from scipy.stats import skew
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#    Date  AveragePrice  Total Volume     4046       4225    4770  region  \
# 0  2015          1.33      64236.62  1036.74   54454.85   48.16  Albany
# 1  2015          1.35      54876.98   674.28   44638.81   58.33  Albany
# 2  2015          0.93     118220.22   794.70  109149.67  130.50  Albany
# 3  2015          1.08      78992.15  1132.00   71976.41   72.58  Albany
# 4  2015          1.28      51039.60   941.48   43838.39   75.78  Albany
#
#    Month  Year
# 0     12    27
# 1     12    20
# 2     12    13
# 3     12     6
# 4     11    29

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Date'],bins=30)
# Out:
# <Axes: xlabel='Date', ylabel='Count'>

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['AveragePrice'],df['Total Volume'],c='Red')
plt.xlabel('The average price of a single avacado')
plt.ylabel('Total number of avacado sold')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['AveragePrice'],df['4225'],c='purple')
plt.xlabel('The average price of a single avacado')
plt.ylabel('Total number o avacado')
plt.ylabel('Total number of avaxado with PLU 4225 sold')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['AveragePrice'],df['4046'],c='green')
plt.xlabel('The average price of a single avacado')
plt.ylabel('Total number of acavado with PLU 4046 sold')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['AveragePrice'],df['4770'],c='black')
plt.xlabel('The average price of a single avacado')
plt.ylabel('Total number of acavado with PLU 4770 sold')
plt.show()

# %%
sns.countplot(x='Date',data=df)
# Out:
# <Axes: xlabel='Date', ylabel='count'>

# %%
sns.countplot(x='Year',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
sns.pairplot(df,diag_kind="hist")

# %% [markdown]
# # USING LABELENCODER FOR CONVERTING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  int32
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   region        18249 non-null  object
#  7   Month         18249 non-null  int32
#  8   Year          18249 non-null  int32
# dtypes: float64(5), int32(3), object(1)
# memory usage: 1.0+ MB

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()
df['region']=le.fit_transform(df['region'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  int32
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   region        18249 non-null  int32
#  7   Month         18249 non-null  int32
#  8   Year          18249 non-null  int32
# dtypes: float64(5), int32(4)
# memory usage: 998.1 KB

# %% [markdown]
# # SKEWNESS

# %%
plt.figure(figsize=(25,20))
for i in enumerate(df.columns):
    plt.subplot(5,3,i[0]+1)
    sns.distplot(df[i[1]],color='g')

# %% [markdown]
# # OUTLIERS

# %%
plt.figure(figsize=(18,10))
for i in enumerate(df):
    plt.subplot(5,3,i[0]+1)
    sns.boxplot(df[i[1]],color='y')

# %% [markdown]
# # ZSCORE

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
print(np.where(z>3))
# Out:
# (array([  346,   359,   783,   787,   788,   790,   791,   792,   794,
#          795,   796,   797,   799,   803,   805,   807,   808,   809,
#          812,   816,   820,   823,   827,  1334,  1347,  1516,  1518,
#         1541,  2340,  2341,  2348,  2351,  2368,  2370,  2652,  2652,
#         2652,  2652,  2653,  2653,  2653,  2653,  2654,  2654,  2654,
#         2654,  2655,  2655,  2655,  2655,  2656,  2656,  2656,  2656,
#         2657,  2657,  2657,  2657,  2658,  2658,  2658,  2658,  2659,
#         2659,  2659,  2659,  2660,  2660,  2660,  2660,  2661,  2661,
#         2661,  2661,  2662,  2662,  2662,  2662,  2663,  2663,  2663,
#         2663,  2664,  2664,  2664,  2664,  2665,  2665,  2665,  2665,
#         2666,  2666,  2666,  2666,  2667,  2667,  2667,  2667,  2668,
#         2668,  2668,  2668,  2669,  2669,  2669,  2669,  2670,  2670,
#         2670,  2670,  2671,  2671,  2671,  2671,  2672,  2672,  2672,
# ...

# %%
df_1=df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",df_1.shape)
# Out:
# with outliers:: (18249, 9)
# After removing outliers:: (17838, 9)

# %% [markdown]
# # DEFINING X & Y

# %%
x = df.drop(['AveragePrice'],axis=1)
y = df['AveragePrice']

# %%
x.shape
# Out:
# (18249, 8)

# %%
y.shape
# Out:
# (18249,)

# %% [markdown]
# # SPLITTING THE DATA FOR TRAIN AND TEST

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LinearRegression


LR = LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state {i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state {i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state 0, The training accuracy is :-0.0872952586784731
# At random state 0, The test accuracy is :-0.09493014478241224
#
#
# At random state 1, The training accuracy is :-0.08909141708082846
# At random state 1, The test accuracy is :-0.08977236177947456
#
#
# At random state 2, The training accuracy is :-0.08870619022522286
# At random state 2, The test accuracy is :-0.09109614863593418
#
#
# At random state 3, The training accuracy is :-0.09077171674482354
# At random state 3, The test accuracy is :-0.0832127191013241
#
#
# At random state 4, The training accuracy is :-0.08878554411799655
# At random state 4, The test accuracy is :-0.090617617923899
#
#
# At random state 5, The training accuracy is :-0.09030487877766913
# At random state 5, The test accuracy is :-0.08329896767832834
#
#
# At random state 6, The training accuracy is :-0.09056381520639378
# At random state 6, The test accuracy is :-0.08480824532208853
#
#
# ...

# %% [markdown]
#  spliting the data into 78% training and 22% testing

# %% [markdown]
# # from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=24)

# %%
x_train.shape
# Out:
# (14234, 8)

# %%
x_test.shape
# Out:
# (4015, 8)

# %%
y_train.shape
# Out:
# (14234,)

# %%
y_test.shape
# Out:
# (4015,)

# %% [markdown]
# # ML MODELS

# %% [markdown]
# # LINEAR REGRESION

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.09035225386764267

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_scoe:',r2_score(LR_predict,y_test))
# Out:
# MSE: 0.14670485167539318
# MAE: 0.30898705477650823
# r2_scoe: -10.339101418554744

# %% [markdown]
# # RANDOM FOREST REGRESOR

# %%
from sklearn.ensemble import RandomForestRegressor

RF = RandomForestRegressor()
RF.fit(x_train,y_train)
print(RF.score(x_train,y_train))
RF_PRED=RF.predict(x_test)
# Out:
# 0.9840815831793349

# %%
print('MSE:',mean_squared_error(RF_PRED,y_test))
print('MAE:', mean_absolute_error(RF_PRED,y_test))
print('r2_score:',r2_score(RF_PRED,y_test))
# Out:
# MSE: 0.01912378383312577
# MAE: 0.09547334993773347
# r2_score: 0.8487100842008883

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_PRED=DTR.predict(x_test)
# Out:
# 1.0

# %%
print('MSE:',mean_squared_error(DTR_PRED,y_test))
print('MAE:',mean_absolute_error(DTR_PRED,y_test))
print('r2_score:',r2_score(DTR_PRED,y_test))
# Out:
# MSE: 0.039306799501867995
# MAE: 0.12602241594022418
# r2_score: 0.7548334058646375
